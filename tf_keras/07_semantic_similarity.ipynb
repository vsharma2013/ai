# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re

# %%
module_url = "https://tfhub.dev/google/universal-sentence-encoder/2" #@param ["https://tfhub.dev/google/universal-sentence-encoder/2", "https://tfhub.dev/google/universal-sentence-encoder-large/3"]

# %%
# Import the Universal Sentence Encoder's TF Hub module
embed = hub.Module(module_url)

# Compute a representation for each message, showing various lengths supported.
word = "Elephant"
sentence = "I am a sentence for which I would like to get its embedding."
paragraph = (
    "Universal Sentence Encoder embeddings also support short paragraphs. "
    "There is no hard limit on how long the paragraph is. Roughly, the longer "
    "the more 'diluted' the embedding will be.")
messages = [word, sentence, paragraph]

# Reduce logging output.
tf.logging.set_verbosity(tf.logging.ERROR)

with tf.Session() as session:
  session.run([tf.global_variables_initializer(), tf.tables_initializer()])
  message_embeddings = session.run(embed(messages))

  for i, message_embedding in enumerate(np.array(message_embeddings).tolist()):
    print("Message: {}".format(messages[i]))
    print("Embedding size: {}".format(len(message_embedding)))
    message_embedding_snippet = ", ".join(
        (str(x) for x in message_embedding[:3]))
    print("Embedding: [{}, ...]\n".format(message_embedding_snippet))
# Out:
# INFO:tensorflow:Using /tmp/tfhub_modules to cache modules.
# INFO:tensorflow:Downloading TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/2'.
# INFO:tensorflow:Downloading https://tfhub.dev/google/universal-sentence-encoder/2: 178.00MB
# INFO:tensorflow:Downloading https://tfhub.dev/google/universal-sentence-encoder/2: 378.00MB
# INFO:tensorflow:Downloading https://tfhub.dev/google/universal-sentence-encoder/2: 558.00MB
# INFO:tensorflow:Downloading https://tfhub.dev/google/universal-sentence-encoder/2: 768.00MB
# INFO:tensorflow:Downloading https://tfhub.dev/google/universal-sentence-encoder/2: 968.00MB
# INFO:tensorflow:Downloaded https://tfhub.dev/google/universal-sentence-encoder/2, Total size: 993.27MB
# INFO:tensorflow:Downloaded TF-Hub Module 'https://tfhub.dev/google/universal-sentence-encoder/2'.
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# NotFoundError: No registered 'Size' OpKernel for GPU devices compatible with node {{node module_apply_default/compound_bigrams/boolean_mask/Prod}} = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](module_apply_default/compound_bigrams/concat_2/_91, ^module_apply_default/compound_bigrams/boolean_mask/Shape_1/_95)
# 	 (OpKernel was found, but attributes didn't match)
# 	.  Registered:  device='XLA_GPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, ..., DT_QINT32, DT_BFLOAT16, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_CPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_GPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_GPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_CPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_CPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='CPU'; out_type in [DT_INT64]
#   device='CPU'; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT32]
#
# 	 [[{{node module_apply_default/compound_bigrams/boolean_mask/Prod}} = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](module_apply_default/compound_bigrams/concat_2/_91, ^module_apply_default/compound_bigrams/boolean_mask/Shape_1/_95)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-4-140110c4483f> in <module>
#      16 with tf.Session() as session:
#      17   session.run([tf.global_variables_initializer(), tf.tables_initializer()])
# ---> 18   message_embeddings = session.run(embed(messages))
#      19
#      20   for i, message_embedding in enumerate(np.array(message_embeddings).tolist()):
#
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# NotFoundError: No registered 'Size' OpKernel for GPU devices compatible with node node module_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/vishal/venv/lib/python3.5/site-packages/tensorflow_hub/native_module.py:514)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](module_apply_default/compound_bigrams/concat_2/_91, ^module_apply_default/compound_bigrams/boolean_mask/Shape_1/_95)
# 	 (OpKernel was found, but attributes didn't match)
# 	.  Registered:  device='XLA_GPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, ..., DT_QINT32, DT_BFLOAT16, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_CPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_GPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_GPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_CPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_CPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='CPU'; out_type in [DT_INT64]
#   device='CPU'; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT32]
#
# 	 [[node module_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/vishal/venv/lib/python3.5/site-packages/tensorflow_hub/native_module.py:514)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](module_apply_default/compound_bigrams/concat_2/_91, ^module_apply_default/compound_bigrams/boolean_mask/Shape_1/_95)]]
#
# Caused by op 'module_apply_default/compound_bigrams/boolean_mask/Prod', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/vishal/venv/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 345, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.5/asyncio/base_events.py", line 1312, in _run_once
#     handle._run()
#   File "/usr/lib/python3.5/asyncio/events.py", line 125, in _run
#     self._callback(*self._args)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/vishal/venv/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/vishal/venv/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/vishal/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/vishal/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)
#   File "/home/vishal/venv/lib/python3.5/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vishal/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vishal/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/vishal/venv/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-140110c4483f>", line 18, in <module>
#     message_embeddings = session.run(embed(messages))
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow_hub/module.py", line 247, in __call__
#     name=name)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow_hub/native_module.py", line 514, in create_apply_graph
#     import_scope=relative_scope_name)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1674, in import_meta_graph
#     meta_graph_or_file, clear_devices, import_scope, **kwargs)[0]
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1696, in _import_meta_graph_with_return_elements
#     **kwargs))
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/meta_graph.py", line 806, in import_scoped_meta_graph_with_return_elements
#     return_elements=return_elements)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/importer.py", line 442, in import_graph_def
#     _ProcessNewOps(graph)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/importer.py", line 234, in _ProcessNewOps
#     for new_op in graph._add_new_tf_operations(compute_devices=False):  # pylint: disable=protected-access
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3440, in _add_new_tf_operations
#     for c_op in c_api_util.new_tf_operations(self)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3440, in <listcomp>
#     for c_op in c_api_util.new_tf_operations(self)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3299, in _create_op_from_tf_operation
#     ret = Operation(c_op, self)
#   File "/home/vishal/venv/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): No registered 'Size' OpKernel for GPU devices compatible with node node module_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/vishal/venv/lib/python3.5/site-packages/tensorflow_hub/native_module.py:514)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](module_apply_default/compound_bigrams/concat_2/_91, ^module_apply_default/compound_bigrams/boolean_mask/Shape_1/_95)
# 	 (OpKernel was found, but attributes didn't match)
# 	.  Registered:  device='XLA_GPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, ..., DT_QINT32, DT_BFLOAT16, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_CPU_JIT'; out_type in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_HALF, DT_UINT32, DT_UINT64]
#   device='XLA_GPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_GPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL, DT_BFLOAT16]
#   device='XLA_CPU'; out_type in [DT_INT64]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='XLA_CPU'; out_type in [DT_INT32]; T in [DT_UINT8, DT_QUINT8, DT_INT8, DT_QINT8, DT_INT32, DT_QINT32, DT_INT64, DT_HALF, DT_FLOAT, DT_DOUBLE, DT_COMPLEX64, DT_BOOL]
#   device='CPU'; out_type in [DT_INT64]
#   device='CPU'; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT32]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_VARIANT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BOOL]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX128]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_COMPLEX64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT8]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_UINT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_INT64]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_DOUBLE]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_FLOAT]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_BFLOAT16]; out_type in [DT_INT32]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT64]
#   device='GPU'; T in [DT_HALF]; out_type in [DT_INT32]
#
# 	 [[node module_apply_default/compound_bigrams/boolean_mask/Prod (defined at /home/vishal/venv/lib/python3.5/site-packages/tensorflow_hub/native_module.py:514)  = Size[T=DT_STRING, out_type=DT_INT32, _device="/job:localhost/replica:0/task:0/device:GPU:0"](module_apply_default/compound_bigrams/concat_2/_91, ^module_apply_default/compound_bigrams/boolean_mask/Shape_1/_95)]]
